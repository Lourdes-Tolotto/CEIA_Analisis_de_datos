# %% [markdown]
# ## **Consigna:**
# ### Buscar un dataset de acceso libre que despierte tu curiosidad o que esté relacionado con tu área de interés. Puede provenir de portales de datos abiertos como Kaggle, datos.gob.ar, data.gov, UCI Machine Learning Repository, etc.
#
# - El dataset debe cumplir con las siguientes condiciones:
# - Entre 200 y 2000 filas
# - Al menos 5 variables (columnas)
# - Mínimo 2 variables numéricas y 2 variables categóricas
# - De acceso público y gratuito

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Airline_Delay_Cause.csv")

# %%
# Visualizar las primeras filas del dataset
df.head()
# Out:
#    year  month carrier       carrier_name airport  \
# 0  2025     11      9E  Endeavor Air Inc.     ABE
# 1  2025     11      9E  Endeavor Air Inc.     ABY
# 2  2025     11      9E  Endeavor Air Inc.     AEX
# 3  2025     11      9E  Endeavor Air Inc.     AGS
# 4  2025     11      9E  Endeavor Air Inc.     ALB
#
#                                         airport_name  arr_flights  arr_del15  \
# 0  Allentown/Bethlehem/Easton, PA: Lehigh Valley ...         87.0       15.0
# 1             Albany, GA: Southwest Georgia Regional         22.0        6.0
# 2           Alexandria, LA: Alexandria International         87.0       15.0
# 3        Augusta, GA: Augusta Regional at Bush Field         58.0       14.0
# 4                   Albany, NY: Albany International         56.0       20.0
#
#    carrier_ct  weather_ct  ...  security_ct  late_aircraft_ct  arr_cancelled  \
# 0        3.66        1.71  ...          0.0              6.40            7.0
# ...

# %%
# Número de filas y columnas del dataset
df.shape
# Out:
# (1849, 21)

# %%
# Nombres de las columnas del dataset
df.columns
# Out:
# Index(['year', 'month', 'carrier', 'carrier_name', 'airport', 'airport_name',
#        'arr_flights', 'arr_del15', 'carrier_ct', 'weather_ct', 'nas_ct',
#        'security_ct', 'late_aircraft_ct', 'arr_cancelled', 'arr_diverted',
#        'arr_delay', 'carrier_delay', 'weather_delay', 'nas_delay',
#        'security_delay', 'late_aircraft_delay'],
#       dtype='str')

# %%
# Información general del dataset
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1849 entries, 0 to 1848
# Data columns (total 21 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   year                 1849 non-null   int64
#  1   month                1849 non-null   int64
#  2   carrier              1849 non-null   str
#  3   carrier_name         1849 non-null   str
#  4   airport              1849 non-null   str
#  5   airport_name         1849 non-null   str
#  6   arr_flights          1849 non-null   float64
#  7   arr_del15            1848 non-null   float64
#  8   carrier_ct           1849 non-null   float64
#  9   weather_ct           1849 non-null   float64
#  10  nas_ct               1849 non-null   float64
#  11  security_ct          1849 non-null   float64
#  12  late_aircraft_ct     1849 non-null   float64
#  13  arr_cancelled        1849 non-null   float64
#  14  arr_diverted         1849 non-null   float64
# ...
